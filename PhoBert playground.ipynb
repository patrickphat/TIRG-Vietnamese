# %%
import torch
from transformers import AutoModel, AutoTokenizer
from tqdm import tqdm

phobert = AutoModel.from_pretrained("vinai/phobert-base")

# For transformers v4.x+: 
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")

# For transformers v3.x: 
# tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
features = []
# INPUT TEXT MUST BE ALREADY WORD-SEGMENTED!
lines = ["Tôi là sinh_viên trường đại_học Công_nghệ .",ng đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .","Tôi là sinh_viên trường đại_học Công_nghệ .",]
for line in tqdm(lines):
    input_ids = torch.tensor([tokenizer.encode(line)])

    with torch.no_grad():
        _, feature = phobert(input_ids)  # Models outputs are now tuples
        features.append(feature)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# 100%|██████████| 17/17 [00:00<00:00, 26.07it/s]

# %%
khối tur5

# %%
import torch
from transformers import AutoModel, AutoTokenizer
from tqdm import tqdm

phobert = AutoModel.from_pretrained("vinai/phobert-base")

# For transformers v4.x+: 
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")

# For transformers v3.x: 
# tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
features = []
# INPUT TEXT MUST BE ALREADY WORD-SEGMENTED!
line = ["Tôi là sinh_viên trường đại_học Công_nghệ . heo con","tôi là bí thư", "đây là chiếc xe"]
line2 = ["sinh_viên"]

input_ids = torch.tensor([tokenizer.encode(line)])
# print(input_ids)
# #features
# with torch.no_grad():
#     feature, _ = phobert(input_ids)  # Models outputs are now tuples
#     print(feature.shape)
# #     import ipdb
# #     ipdb.set_trace()

# #     #features.append(feature)
# # a = 1

print(tokenizer.encode(line2))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# [0, 649, 2]

# %%
input_ids = torch.tensor([tokenizer.encode(line)])
with torch.no_grad():
    _, feature = phobert(input_ids)

# %%
feature.shape
# Out:
# torch.Size([1, 768])

# %%
# !pip install vncorenlp
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 4.5 MB/s eta 0:00:01
# ...
#   Created wheel for vncorenlp: filename=vncorenlp-1.0.3-py3-none-any.whl size=2645935 sha256=9353d85398234174963416d765db06490c5acce30c1e7dba7231f7533133f72b
#   Stored in directory: /mnt/ai_filestore/home/nick/.cache/pip/wheels/41/17/db/dbd7fe2c88df07b4acb8469d814d99080f78b20c90f53b5f2e
# Successfully built vncorenlp
# ...

# %%
input_ids.shape
# Out:
# torch.Size([1, 5])

# %%
# Load rdrsegmenter from VnCoreNLP
from vncorenlp import VnCoreNLP
rdrsegmenter = VnCoreNLP("vncorenlp/VnCoreNLP-1.1.1.jar", annotators="wseg", max_heap_size='-Xmx500m') 

# Input 
text = "Ông Nguyễn Khắc Chúc  đang làm việc tại Đại học Quốc gia Hà Nội. Bà Lan, vợ ông Chúc, cũng làm việc tại đây."

# To perform word (and sentence) segmentation
sentences = rdrsegmenter.tokenize(text) 
for sentence in sentences:
	print(" ".join(sentence))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/nick/miniconda3/envs/thesis/lib/python3.6/site-packages/vncorenlp/vncorenlp.py in __init__(self, address, port, timeout, annotators, max_heap_size, quiet)
#      52             try:
# ---> 53                 subprocess.check_call(['java', '-version'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
#      54             except FileNotFoundError:
#
# /home/nick/miniconda3/envs/thesis/lib/python3.6/subprocess.py in check_call(*popenargs, **kwargs)
#     305     """
# --> 306     retcode = call(*popenargs, **kwargs)
#     307     if retcode:
#
# /home/nick/miniconda3/envs/thesis/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     286     """
# --> 287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
#
# ...

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%sh
# # Install the vncorenlp python wrapper
# pip3 install vncorenlp
#
# # Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter)
# mkdir -p vncorenlp/models/wordsegmenter
# wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# mv VnCoreNLP-1.1.1.jar vncorenlp/
# mv vi-vocab vncorenlp/models/wordsegmenter/
# mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/
# Out:
# ...
# --2020-12-11 03:59:58--  https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27412575 (26M) [application/octet-stream]
# Saving to: ‘VnCoreNLP-1.1.1.jar’
#
#      0K .......... .......... .......... .......... ..........  0% 5.38M 5s
#     50K .......... .......... .......... .......... ..........  0% 4.04M 6s
#    100K .......... .......... .......... .......... ..........  0% 14.9M 4s
#    150K .......... .......... .......... .......... ..........  0% 21.2M 4s
#    200K .......... .......... .......... .......... ..........  0% 7.27M 4s
#    250K .......... .......... .......... .......... ..........  1% 26.9M 3s
# ...
